# %%
#https://github.com/fchollet/deep-learning-models

# %%
# !pip install Keras==2.0.0

# %%
# !git clone https://github.com/fchollet/deep-learning-models.git
# Out:
# fatal: destination path 'deep-learning-models' already exists and is not an empty directory.

# %%
# !ls deep-learning-models
# !cp ./deep-learning-models/imagenet_utils.py .
# !cp ./deep-learning-models/resnet50.py .
# !cp ./deep-learning-models/vgg16.py .
# Out:
# audio_conv_utils.py	inception_v3.py  music_tagger_crnn.py  vgg16.py
# imagenet_utils.py	LICENSE		 README.md	       vgg19.py
# inception_resnet_v2.py	mobilenet.py	 resnet50.py	       xception.py

# %%
# !wget https://www.dropbox.com/s/mmatzj3k5cj5rak/Horton-the-Elephant.png
# Out:
# --2018-03-12 12:03:38--  https://www.dropbox.com/s/mmatzj3k5cj5rak/Horton-the-Elephant.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.1, 2620:100:601c:1::a27d:601
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dl.dropboxusercontent.com/content_link/aNyuJxnYRJaF7YRHItk4XwOwSfq6bcNozxcTP6V86gBZDTfpRAfYWHrQW73Mmw9i/file [following]
# --2018-03-12 12:03:38--  https://dl.dropboxusercontent.com/content_link/aNyuJxnYRJaF7YRHItk4XwOwSfq6bcNozxcTP6V86gBZDTfpRAfYWHrQW73Mmw9i/file
# Resolving dl.dropboxusercontent.com (dl.dropboxusercontent.com)... 162.125.6.6, 2620:100:601c:6::a27d:606
# Connecting to dl.dropboxusercontent.com (dl.dropboxusercontent.com)|162.125.6.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1580732 (1.5M) [image/png]
# Saving to: ‘Horton-the-Elephant.png’
#
# ...

# %%
import numpy as np
from vgg16 import VGG16
from keras.preprocessing import image
from imagenet_utils import preprocess_input

model = VGG16(weights='imagenet', include_top=False)

img_path = 'Horton-the-Elephant.png'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

features = model.predict(x)
print(features.shape)
# Out:
# (1, 7, 7, 512)

# %%
# !ls
# Out:
# datalab		      Horton-the-Elephant.png  predictions.csv	resnet50.py
# deep-learning-models  imagenet_utils.py        __pycache__	vgg16.py

# %%
from resnet50 import ResNet50
from keras.preprocessing import image
from imagenet_utils import preprocess_input, decode_predictions

model = ResNet50(weights='imagenet')

img_path = 'elephant.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
print('Predicted:', decode_predictions(preds))
# print: [[u'n02504458', u'African_elephant']]
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-74a75d6d4d14> in <module>()
#       3 from imagenet_utils import preprocess_input, decode_predictions
#       4
# ----> 5 model = ResNet50(weights='imagenet')
#       6
#       7 img_path = 'elephant.jpg'
#
# /content/resnet50.py in ResNet50(include_top, weights, input_tensor, input_shape, pooling, classes)
#     191                                       min_size=197,
#     192                                       data_format=K.image_data_format(),
# --> 193                                       include_top=include_top)
#     194
#     195     if input_tensor is None:
#
# TypeError: _obtain_input_shape() got an unexpected keyword argument 'include_top'
