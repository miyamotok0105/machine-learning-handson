# %%
import numpy as np
from sympy import *
import matplotlib.pyplot as plt
# %matplotlib inline
init_printing()
import chainer
from chainer import cuda, Function, gradient_check, report, training, utils, Variable
from chainer import datasets, iterators, optimizers, serializers
from chainer import Link, Chain, ChainList
import chainer.functions as F
import chainer.links as L
from chainer.training import extensions

# %% [markdown]
# # relu関数

# %%
from PIL import Image
im = Image.open("./img/relu.png", "r")
plt.imshow(np.array(im))

# %%
x = np.arange(-2, 4, 2).astype('f')
y = F.relu(x)
plt.plot(y.data)

# %%
x = np.array([[-1, 0], [2, -3], [-2, 1]], 'f')
plt.plot(x)
np.any(x < 0)
# Out:
# True

# %%
y = F.relu(x)
plt.plot(y.data)
np.any(y.data < 0)
# Out:
# False

# %% [markdown]
# # leaky_relu関数

# %%
from PIL import Image
im = Image.open("./img/leaky_relu.png", "r")
plt.imshow(np.array(im))

# %%
x = np.arange(-2, 4, 2).astype('f')
y = F.leaky_relu(x, slope=0.2).data
plt.plot(y.data)

# %%
x = np.array([[-1, 0], [2, -3], [-2, 1]], 'f')
plt.plot(x)

# %%
y = F.leaky_relu(x, slope=0.2).data
plt.plot(y.data)

# %% [markdown]
# # elu関数

# %%
from PIL import Image
im = Image.open("./img/elu.png", "r")
plt.imshow(np.array(im))
#https://arxiv.org/abs/1511.07289

# %%
x = np.arange(-2, 4, 2).astype('f')
y = F.elu(x, alpha=1.)
plt.plot(y.data)

# %% [markdown]
# # crelu関数

# %%
from PIL import Image
im = Image.open("./img/crelu.png", "r")
plt.imshow(np.array(im))
#https://arxiv.org/abs/1603.05201

# %%
x = np.array([[-1, 0], [2, -3]], 'f')
plt.plot(x)

# %%
y = F.crelu(x, axis=1)
print(y.data)
plt.plot(y.data)
# Out:
# [[ 0.  0.  1.  0.]
#  [ 2.  0.  0.  3.]]
# ...

# %% [markdown]
# # softplus関数

# %%
from PIL import Image
im = Image.open("./img/softplus.png", "r")
plt.imshow(np.array(im))

# %%
x = np.arange(-2, 4, 2).astype('f')
x.shape
plt.plot(x)

# %%
#betaの調整ができる
x_list = []
x_list.append(F.softplus(x, beta=0.1).data)
x_list.append(F.softplus(x, beta=0.5).data)
x_list.append(F.softplus(x, beta=1.0).data)

# %%
print(x_list[0])
plt.plot(x_list[0])
# Out:
# [ 5.98138857  6.93147182  7.98138857]

# %%
print(x_list[1])
plt.plot(x_list[1])
# Out:
# [ 0.62652338  1.38629436  2.62652349]

# %%
print(x_list[2])
plt.plot(x_list[2])
# Out:
# [ 0.12692802  0.69314718  2.12692809]
