# %%
def compute_mean(dataset):
        print('compute mean image')
        sum_image = 0
        N = len(dataset)
        for i, (image, _) in enumerate(dataset):
            sum_image += image
        return sum_image / N

mean_iamge = compute_mean(train)

# %%
mean_iamge.shape

# %%
plt.figure(figsize=(2,2))
plt.imshow(np.rollaxis(mean_iamge, axis=0, start=3))

# %%
def transform_data(image):
        image -= mean_iamge
        image *= (1.0 / 255.0)  # Scale to [0, 1]
        return image

# %%
transform_train = [(transform_data(image), label) for image, label in train]
transform_test = [(transform_data(image), label) for image, label in test]

# %%
transform_train[0][0].shape

# %%
np.rollaxis(transform_train[0][0], axis=0, start=3).shape
