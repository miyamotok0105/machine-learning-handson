# %% [markdown]
# high-level apiについて。エスティメータは以下のアクションをカプセル化します。
#
# - training
# - evaluation
# - prediction
# - export for serving
#
# あらかじめ作ったEstimatorsを使用するか、独自のカスタムEstimatorを書くことができます。
# すべての見積もり者は、事前に作成されたものであれカスタムであれ、tf.estimator.Estimatorクラスに基づくクラスです

# %% [markdown]
# # あらかじめ作成された見積もりプログラムの構造
